# %% [markdown]
# # Limpieza de bienes raíces
#
# Este es un conjunto de datos (dataset) reales que fue descargado usando técnicas de web scraping. La data contiene registros de **Fotocasa**, el cual es uno de los sitios más populares de bienes raíces en España. Por favor no hagas esto (web scraping) a no ser que sea para propósitos académicos.
#
# El dataset fue descargado hace algunos años por Henry Navarro y en ningún caso se obtuvo beneficio económico de ello.
#
# Contiene miles de datos de casas reales publicadas en la web www.fotocasa.com. Tu objetivo es extraer tanta información como sea posible con el conocimiento que tienes hasta ahora de ciencia de datos, por ejemplo ¿cuál es la casa más cara en todo el dataset?
#
# Empecemos precisamente con esa pregunta... ¡Buena suerte!

# %% [markdown]
# #### Ejercicio 00. Lee el dataset assets/real_estate.csv e intenta visualizar la tabla (★☆☆)

# %%
import pandas as pd

import matplotlib.pyplot as plt

import numpy as np 

# Este archivo CSV contiene puntos y comas en lugar de comas como separadores
datos = pd.read_csv('assets/real_estate.csv', sep=';')
datos
# Out:
#        Unnamed: 0  id_realEstates  isNew                    realEstate_name  \
# 0               1       153771986  False            ferrari 57 inmobiliaria
# 1               2       153867863  False  tecnocasa fuenlabrada ferrocarril
# 2               3       153430440  False                 look find boadilla
# 3               4       152776331  False  tecnocasa fuenlabrada ferrocarril
# 4               5       153180188  False            ferrari 57 inmobiliaria
# ...           ...             ...    ...                                ...
# 15330       15331       153901377  False                infocasa consulting
# 15331       15332       150394373  False                inmobiliaria pulpon
# 15332       15333       153901397  False             tecnocasa torrelodones
# 15333       15334       152607440  False                inmobiliaria pulpon
# 15334       15335       153901356  False                infocasa consulting
#
# ...

# %% [markdown]
# #### Ejercicio 01. ¿Cuál es la casa más cara en todo el dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle del Prado, Nº20 es la más cara y su precio es de 5000000 USD`

# %%
# TODO

id_precio_max = datos["price"].idxmax()

casa_valor_max = datos.iloc[id_precio_max]

print("La casa más cara tiene un valor de: ", casa_valor_max["price"])
print(" y esta ubicada en: ", casa_valor_max["address"])
# Out:
# La casa más cara tiene un valor de:  8500000
#  y esta ubicada en:  El Escorial

# %% [markdown]
# #### Ejercicio 02. ¿Cuál es la casa más barata del dataset? (★☆☆)
#
# Imprime la dirección y el precio de la casa seleccionada. Por ejemplo:
#
# `La casa con dirección en Calle Alcalá, Nº58 es la más barata y su precio es de 12000 USD`

# %%
# TODO

id_precio_min = datos["price"].idxmin()

casa_valor_min = datos.iloc[id_precio_min]
print("la casa más barata tiene un precio de: ", casa_valor_min["price"])
print("y esta ubicada en: ", casa_valor_min["address"])
# Out:
# la casa más barata tiene un precio de:  0
# y esta ubicada en:  Parla

# %% [markdown]
# #### Ejercicio 03. ¿Cuál es la casa más grande y la más pequeña del dataset? (★☆☆)
#
# Imprime la dirección y el área de las casas seleccionadas. Por ejemplo:
#
# `La casa más grande está ubicada en Calle Gran Vía, Nº38 y su superficie es de 5000 metros`
#
# `La casa más pequeña está ubicada en Calle Mayor, Nº12 y su superficie es de 200 metros`

# %%
# TODO

id_grande = datos["surface"].idxmax()

casa_grande = datos.iloc[id_grande]

print("La casa más grade tiene una superficie de :", casa_grande["surface"])
print("y esta ubicada en: ", casa_grande["address"])


id_peque = datos["surface"].idxmin()

casa_peque = datos.iloc[id_peque]

print("La casa más pequeña tiene una superficie de :", casa_peque["surface"])
print("y esta ubicada en: ", casa_peque["address"])
# Out:
# La casa más grade tiene una superficie de : 249000.0
# y esta ubicada en:  Sevilla la Nueva
# La casa más pequeña tiene una superficie de : 15.0
# y esta ubicada en:  Calle Amparo,  Madrid Capital

# %% [markdown]
# #### Ejercicio 04. ¿Cuantas poblaciones (columna level5) contiene el dataset? (★☆☆)
#
# Imprime el nombre de las poblaciones separadas por coma. Por ejemplo:
#
# `> print(populations)`
#
# `population1, population2, population3, ...`

# %%
# TODO

level_5 = datos["level5"].unique().size

print("la cantidad de población level 5:", level_5)
# Out:
# la cantidad de población level 5: 168

# %% [markdown]
# #### Ejercicio 05. ¿El dataset contiene valores no admitidos (NAs)? (★☆☆)
#
# Imprima un booleano (`True` o `False`) seguido de la fila/columna que contiene el NAs.

# %%
# TODO

print("cantidad de registros antes de la limpieza", datos["realEstate_name"].count())

datos["Tiene_NA"] = datos.isna().any(axis=1)


limpieza = datos["Tiene_NA"].sum()
print("Cantidad de datos despues de la limpieza ", limpieza)
# Out:
# cantidad de registros antes de la limpieza 15325
# Cantidad de datos despues de la limpieza  15335

# %% [markdown]
# #### Ejercicio 06. Elimina los NAs del dataset, si aplica (★★☆)
#
# Imprima una comparación entre las dimensiones del DataFrame original versus el DataFrame después de las eliminaciones.

# %%
# TODO

#datos = datos[datos["Tiene_NA"] == False]


#datos.to_csv('assets/datos_modificados.csv')

#datos = pd.read_csv ('assets/datos_modificados.csv')

# %% [markdown]
# #### Ejercicio 07. ¿Cuál la media de precios en la población (columna level5) de "Arroyomolinos (Madrid)"? (★★☆)
#
# Imprima el valor obtenido.

# %%
# TODO

poblacion_arroyomo = datos[datos["level5"] == "Arroyomolinos (Madrid)"]

media_a = poblacion_arroyomo["price"].mean()

print("La media de precios de la población Arroyomolinos (Madrid) es de : {:.2f} ".format(media_a))
# Out:
# La media de precios de la población Arroyomolinos (Madrid) es de : 294541.60

# %% [markdown]
# #### Ejercicio 08. Trazar el histograma de los precios para la población (level5 column) de "Arroyomolinos (Madrid)" y explica qué observas (★★☆)
#
# Imprime el histograma de los precios y escribe en la celda del Markdown un breve análisis del trazado.

# %%
plt.figure(figsize = (20, 16))

plt.hist( poblacion_arroyomo["price"], bins = 30, alpha = 0.7)

plt.title("Histograma de precios en Arroyomolinos (Madrid)")
plt.show()

#Observamos 
# Una concentración de precios en el extremo bajo sugiere una predominancia de viviendas más asequibles, mientras que una distribución amplia o desplazada hacia la derecha indica variabilidad en el mercado, con presencia de propiedades más exclusivas o costosas.

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 09. ¿Son los precios promedios de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios y escribe una conclusión sobre ellos.

# %%
# TODO

poblacion_v = datos[datos["level5"] == "Valdemorillo"]

poblacion_g = datos[datos["level5"] == "Galapagar"]

media_v= poblacion_v["price"].mean()

media_g= poblacion_g["price"].mean()

print("La media de precios de la población  Valdemorillo es de : {:.2f} ".format(media_v))

print("La media de precios de la población  Galapagar es de : {:.2f} ".format(media_g))

if media_g == media_v :
    print ("Son iguales los precios promedios ")
else: 
    print("Son diferente los precios promedios")
# Out:
# La media de precios de la población  Valdemorillo es de : 363860.29
# La media de precios de la población  Galapagar es de : 360063.20
# Son diferente los precios promedios

# %% [markdown]
# #### Ejercicio 10. ¿Son los promedios de precio por metro cuadrado (precio/m2) de "Valdemorillo" y "Galapagar" los mismos? (★★☆)
#
# Imprime ambos promedios de precio por metro cuadrado y escribe una conclusión sobre ellos.
#
# Pista: Crea una nueva columna llamada `pps` (*price per square* o precio por metro cuadrado) y luego analiza los valores.

# %%
# TODO

poblacion_v["precio_m2"]= poblacion_v["price"] / poblacion_v["surface"]

poblacion_g["precio_m2"]= poblacion_g["price"] / poblacion_g["surface"]

media_v= poblacion_v["precio_m2"].mean()

media_g= poblacion_g["precio_m2"].mean()

print("La media de precios de la población por m2 de Valdemorillo es de : {:.2f} ".format(media_v))

print("La media de precios de la población por m2 de Galapagar es de : {:.2f} ".format(media_g))

if media_g == media_v :
    print ("Son iguales los precios promedios ")
else: 
    print("Son diferente los precios promedios")
# Out:
# La media de precios de la población por m2 de Valdemorillo es de : 1317.95
# La media de precios de la población por m2 de Galapagar es de : 1606.32
# Son diferente los precios promedios
# /tmp/ipykernel_12635/1205381025.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poblacion_v["precio_m2"]= poblacion_v["price"] / poblacion_v["surface"]
# /tmp/ipykernel_12635/1205381025.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %% [markdown]
# #### Ejercicio 11. Analiza la relación entre la superficie y el precio de las casas. (★★☆)
#
# Pista: Puedes hacer un `scatter plot` y luego escribir una conclusión al respecto.

# %%
plt.figure(figsize = (10, 20))

plt.scatter(datos["surface"], datos["price"], label = "Seno de X")

plt.title("Gráfico de dispersión")
plt.legend()
plt.show()

# Observamos
#Generalmente, una relación lineal indica que las propiedades más grandes tienden a ser más costosas, aunque se pueden encontrar outliers, como propiedades pequeñas de alto valor (ubicaciones premium o lujosas) o grandes propiedades con precios más bajos de lo esperado.

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 12. ¿Cuántas agencia de bienes raíces contiene el dataset? (★★☆)
#
# Imprime el valor obtenido.

# %%
# TODO

c_agencias = datos["realEstate_name"].unique()

print("La cantidad de agencias es: ", c_agencias.size)
# Out:
# La cantidad de agencias es:  1822

# %% [markdown]
# #### Ejercicio 13. ¿Cuál es la población (columna level5) que contiene la mayor cantidad de casas?(★★☆)
#
# Imprima la población y el número de casas.

# %%
# TODO

frecuencias = datos["level5"].value_counts()

# Encontrar el valor que más se repite y su frecuencia
valor_mas_frecuente = frecuencias.idxmax()

frecuencia_maxima = frecuencias.max()

print("El valor que más se repite es: ", valor_mas_frecuente)

print(" la cantidad de veces es : ", frecuencia_maxima)
# Out:
# El valor que más se repite es:   Madrid Capital
#  la cantidad de veces es :  6643

# %% [markdown]
# #### Ejercicio 14. Ahora vamos a trabajar con el "cinturón sur" de Madrid. Haz un subconjunto del DataFrame original que contenga las siguientes poblaciones (columna level5): "Fuenlabrada", "Leganés", "Getafe", "Alcorcón" (★★☆)
#
# Pista: Filtra el DataFrame original usando la columna `level5` y la función `isin`.

# %%
# TODO

poblacion =["Fuenlabrada", "Leganés", "Getafe","Alcorcón"]
p_level5 = datos[datos["level5"].isin(poblacion)]

# %% [markdown]
# #### Ejercicio 15. Traza un gráfico de barras de la mediana de los precios y explica lo que observas (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprima un gráfico de barras de la mediana de precios y escriba en la celda Markdown un breve análisis sobre el gráfico.

# %%
# TODO: las casas en las poblaciones de Getafe y Alcorcon son mucho mas costosas, ya que en la media dio valores superiores 
# mientras que la mas barata es Fuenlabrada   


media_poblacion = p_level5.groupby("level5")["price"].median()


plt.figure(figsize=(10, 6))
media_poblacion.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title('Media del Precio de Casas por Población')
plt.xlabel("Población")
plt.ylabel('Precio')


# Mostrar el gráfico
plt.show()

# Se observa
#muestra la accesibilidad relativa de cada área, ayudando a identificar cuál de estas poblaciones tiene viviendas más asequibles o costosas en promedio.

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 16. Calcula la media y la varianza de muestra para las siguientes variables: precio, habitaciones, superficie y baños (debes usar el subconjunto obtenido del Ejercicio 14) (★★★)
#
# Imprime ambos valores por cada variable.

# %%
# TODO

#calcular la media

m_level5_precio = p_level5["price"].mean()

m_level5_room = p_level5["rooms"].mean()

m_level5_surface = p_level5["surface"].mean()

m_level5_bathroom = p_level5["bathrooms"].mean()

print("La media de las poblaciones Fuenlabrada, Leganés, Getafe y Alcorcón son: ")

print("Precio : {:.2f}".format(m_level5_precio))
print("Habitaciones :{:.2f}".format(m_level5_room))
print("Superficie: {:.2f} ".format(m_level5_surface))
print("Baños: {:.2f} ".format(m_level5_bathroom))

# Varianza

v_level5_precio = p_level5["price"].var()

v_level5_room = p_level5["rooms"].var()

v_level5_surface = p_level5["surface"].var()

v_level5_bathroom = p_level5["bathrooms"].var()

print("La varianza de las poblaciones Fuenlabrada, Leganés, Getafe y Alcorcón son: ")

print("Precio : {:.2f} ".format( v_level5_precio))
print("Habitaciones : {:.2f} ".format( v_level5_room))
print("Superficie: {:.2f} ".format(v_level5_surface))
print("Baños: {:.2f} ".format(v_level5_bathroom))
# Out:
# La media de las poblaciones Fuenlabrada, Leganés, Getafe y Alcorcón son:
# Precio : 223094.48
# Habitaciones :3.02
# Superficie: 111.75
# Baños: 1.63
# La varianza de las poblaciones Fuenlabrada, Leganés, Getafe y Alcorcón son:
# Precio : 14921367508.05
# Habitaciones : 0.72
# Superficie: 4263.05
# Baños: 0.57

# %% [markdown]
# #### Ejercicio 17. ¿Cuál es la casa más cara de cada población? Debes usar el subset obtenido en la pregunta 14 (★★☆)
#
# Imprime tanto la dirección como el precio de la casa seleccionada de cada población. Puedes imprimir un DataFrame o una sola línea para cada población.

# %%
# TODO

id_max = p_level5.groupby("level5")["price"].idxmax()

casa_max = p_level5.loc[id_max]

print("Las casas más caras son : ",casa_max["level5"] , casa_max["price"])
# Out:
# Las casas más caras son :  5585        Alcorcón
# 11561    Fuenlabrada
# 2881          Getafe
# 10412        Leganés
# Name: level5, dtype: object 5585      950000
# 11561     490000
# 2881     1050000
# 10412     650000
# Name: price, dtype: int64

# %% [markdown]
# #### Ejercicio 18. Normaliza la variable de precios para cada población y traza los 4 histogramas en el mismo gráfico (debes usar el subconjunto obtenido en la pregunta 14) (★★★)
#
# Para el método de normalización, puedes usar el que consideres adecuado, no hay una única respuesta correcta para esta pregunta. Imprime el gráfico y escribe en la celda de Markdown un breve análisis sobre el gráfico.
#
# Pista: Puedes ayudarte revisando la demostración multihist de Matplotlib.

# %%
# TODO
from sklearn.preprocessing import MinMaxScaler

# Filtrar el DataFrame original para incluir solo las poblaciones especificadas
poblacion = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
p_level5 = datos[datos["level5"].isin(poblacion)]


# Dividir en conjuntos de entrenamiento 
X_train = p_level5[["price"]]

# Normalizar los precios utilizando MinMaxScaler
scaler = MinMaxScaler()
scaler.fit(X_train)

# Aplicar la transformación de escalado
X_train_scal = scaler.transform(X_train)
X_train_scal = pd.DataFrame(X_train_scal, index=X_train.index, columns=["price_normalized"])


print(X_train_scal.head())

p_level5["price_normalized"] = X_train_scal
# Out:
#      price_normalized
# 1            0.084762
# 3            0.084762
# 85           0.101905
# 94           0.304762
# 109          0.404762
# /tmp/ipykernel_12635/1299633002.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   p_level5["price_normalized"] = X_train_scal

# %%
# Graficar histogramas de precios normalizados para cada población
plt.figure(figsize=(10, 6))
colors = ['skyblue', 'orange', 'green', 'red']

for i, pop in enumerate(poblacion):
    subset = p_level5[p_level5["level5"] == pop]["price_normalized"]
    plt.hist(subset, bins=10, alpha=0.5, label=pop, color=colors[i])

plt.title('Histogramas Normalizados de Precios por Población')
plt.xlabel('Precio Normalizado')
plt.ylabel('Frecuencia')
plt.legend()
plt.grid(axis='y')
plt.show()

#Se observa 
# La normalización ajusta los valores de precios a un rango común, facilitando una comparación directa de la estructura de precios sin importar las diferencias de escala entre poblaciones. Al observar los histogramas juntos, se pueden identificar patrones distintivos en cada población, como si una población tiene una mayor densidad de viviendas en un rango de precios medio (indicando estabilidad), mientras que otra muestra más variabilidad, sugiriendo una mezcla de zonas económicas dentro de la misma población.

# %% [markdown]
# **TODO: Markdown**. Para escribir aquí, haz doble clic en esta celda, elimina este contenido y coloca lo que quieras escribir. Luego ejecuta la celda.

# %% [markdown]
# #### Ejercicio 19. ¿Qué puedes decir sobre el precio por metro cuadrado (precio/m2) entre los municipios de 'Getafe' y 'Alcorcón'? Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
#
# Pista: Crea una nueva columna llamada `pps` (price per square en inglés) y luego analiza los valores

# %%
# TODO

poblacion_g = p_level5.loc[p_level5["level5"] == "Getafe"]

poblacion_a = p_level5.loc[p_level5["level5"] == "Alcorcón"]

poblacion_g["pps"] = poblacion_g["price"] / poblacion_g["surface"]

poblacion_a["pps"] = poblacion_a["price"] / poblacion_a["surface"]

media_g = poblacion_g["pps"].mean()

media_a = poblacion_g["pps"].mean()

print(" La población Gatafe tiene una media de precio por m2 de: {:.2f} ".format(media_g))
print(" La población Alcorcón tiene una media de precio por m2 de : {:.2f}".format(media_a))
# Out:
#  La población Gatafe tiene una media de precio por m2 de: 2066.31
#  La población Alcorcón tiene una media de precio por m2 de : 2066.31
# /tmp/ipykernel_12635/912757536.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poblacion_g["pps"] = poblacion_g["price"] / poblacion_g["surface"]
# /tmp/ipykernel_12635/912757536.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   poblacion_a["pps"] = poblacion_a["price"] / poblacion_a["surface"]

# %% [markdown]
# #### Ejercicio 20. Realiza el mismo gráfico para 4 poblaciones diferentes (columna level5) y colócalos en el mismo gráfico. Debes usar el subconjunto obtenido en la pregunta 14 (★★☆)
# Pista: Haz un diagrama de dispersión de cada población usando subgráficos (subplots).

# %%
# TODO

# Crear un DataFrame filtrado con solo las poblaciones especificadas y con precios normalizados
poblacion = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
p_level5_normalized = p_level5[p_level5["level5"].isin(poblacion)]

# Colores para cada población
colors = ['skyblue', 'orange', 'green', 'red']

# Preparar el gráfico de dispersión
plt.figure(figsize=(12, 8))

# Trazar el diagrama de dispersión para cada población en el mismo gráfico
for i, pop in enumerate(poblacion):
    subset = p_level5_normalized[p_level5_normalized["level5"] == pop]
    plt.scatter(subset["surface"], subset["price_normalized"], color=colors[i], alpha=0.6, label=pop)

# Configurar el gráfico
plt.title('Diagrama de Dispersión de Precio Normalizado vs Superficie por Población')
plt.xlabel('Superficie (m²)')
plt.ylabel('Precio Normalizado')
plt.legend(title='Población')
plt.grid(True)

# Mostrar el gráfico
plt.show()

# Se observa
#Nos permite identificar si cada área tiene un comportamiento de mercado único, como ciertas zonas donde el precio no está directamente correlacionado con el tamaño de la propiedad (posiblemente debido a factores de ubicación o exclusividad)

# %% [markdown]
# #### Ejercicio 21. Realiza un trazado de las coordenadas (columnas latitud y longitud) del cinturón sur de Madrid por color de cada población (debes usar el subconjunto obtenido del Ejercicio 14) (★★★★)
#
# Ejecuta la siguiente celda y luego comienza a codear en la siguiente. Debes implementar un código simple que transforme las columnas de coordenadas en un diccionario de Python (agrega más información si es necesario) y agrégala al mapa.

# %%
from ipyleaflet import Map, Marker, MarkerCluster, basemaps

# Crear el DataFrame 
poblacion = ["Fuenlabrada", "Leganés", "Getafe", "Alcorcón"]
p_level5 = datos[datos["level5"].isin(poblacion)]

# Crear un mapa centrado en Madrid usando el basemap
mapa = Map(center=(40.4, -3.7), zoom=10, min_zoom=1, max_zoom=20, basemap=basemaps.OpenStreetMap.Mapnik)

# Asignar colores 
colores = {
    "Fuenlabrada": "blue",
    "Leganés": "green",
    "Getafe": "red",
    "Alcorcón": "purple"
}

# Crear marcadores y clusters para cada población
for pop in poblacion:
    marcadores = []
    subset = p_level5[p_level5["level5"] == pop]
    
    for _, row in subset.iterrows():
        # Verificar que haya datos de latitud y longitud válidos
        if pd.notna(row["latitude"]) and pd.notna(row["longitude"]):
            marker = Marker(location=(row["latitude"], row["longitude"]), title=pop, draggable=False)
            marker.icon_color = colores[pop]  # Color asignado según la población
            marcadores.append(marker)
    
    # Crear un cluster de marcadores para la población actual y añadirlo al mapa
    cluster = MarkerCluster(markers=marcadores)
    mapa.add_layer(cluster)

# Mostrar el mapa
mapa
# Out:
# Map(center=[40.4, -3.7], controls=(ZoomControl(options=['position', 'zoom_in_text', 'zoom_in_title', 'zoom_out…
